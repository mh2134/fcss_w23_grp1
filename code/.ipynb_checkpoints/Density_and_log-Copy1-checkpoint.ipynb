# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Metropolitan area

# %%
# read df
df = pd.read_csv(r'../data/df_allmetro_all.csv')

# calculate relative crime
df.loc[:, 'crime/population'] = df['Nr_Crimes'] / df['population']
df.loc[:, 'density'] = df['population'] / df['area']
df.loc[:, 'crime/density'] = df['Nr_Crimes'] / df['density']

# log columns
df.loc[:, 'crime/population_log'] = np.log(df['crime/population'] + 1e-20)  # add small number to avoid log(0)
df.loc[:, 'density_log'] = np.log(df['density'] + 1e-20)
df.loc[:, 'crime/density_log'] = np.log(df['crime/density'] + 1e-20)
df.loc[:, 'unemp_log'] = np.log(df['unemp per Tsd.'] + 1e-20)
df.loc[:, 'gdp_log'] = np.log(df['gdp'] + 1e-20)

# drop aggregates
df = df[df['metroreg'].str.len() >= 3]

# drop values
df = df[(df['unit'] == 'EUR_HAB:Euro per inhabitant') & (df['dfunemp_sex'] == 'M:Males')]

df.dropna()
# Out:
#        metroreg  TIME_PERIOD                         unit      gdp     area  \
# 784     AT001MC         2014  EUR_HAB:Euro per inhabitant  42600.0   8817.0
# 785     AT001MC         2014  EUR_HAB:Euro per inhabitant  42600.0   8817.0
# 786     AT001MC         2014  EUR_HAB:Euro per inhabitant  42600.0   8817.0
# 787     AT001MC         2014  EUR_HAB:Euro per inhabitant  42600.0   8817.0
# 840     AT001MC         2015  EUR_HAB:Euro per inhabitant  43200.0   8817.0
# ...         ...          ...                          ...      ...      ...
# 136671    SK_NM         2020  EUR_HAB:Euro per inhabitant  14000.0  40228.0
# 136672    SK_NM         2020  EUR_HAB:Euro per inhabitant  14000.0  40228.0
# 136673    SK_NM         2020  EUR_HAB:Euro per inhabitant  14000.0  40228.0
# 136674    SK_NM         2020  EUR_HAB:Euro per inhabitant  14000.0  40228.0
# 136675    SK_NM         2020  EUR_HAB:Euro per inhabitant  14000.0  40228.0
#
#         population dfunemp_sex                 dfunemp_age  unemp per Tsd.  \
# 784      2681273.0     M:Males  Y15-24:From 15 to 24 years            14.0
# 785      2681273.0     M:Males  Y15-24:From 15 to 24 years            14.0
# 786      2681273.0     M:Males  Y15-24:From 15 to 24 years            14.0
# 787      2681273.0     M:Males  Y15-24:From 15 to 24 years            14.0
# 840      2720557.0     M:Males  Y15-24:From 15 to 24 years            14.4
# ...            ...         ...                         ...             ...
# 136671   3986821.0     M:Males  Y15-24:From 15 to 24 years            13.2
# 136672   3986821.0     M:Males  Y15-74:From 15 to 74 years            72.9
# 136673   3986821.0     M:Males  Y15-74:From 15 to 74 years            72.9
# 136674   3986821.0     M:Males  Y15-74:From 15 to 74 years            72.9
# 136675   3986821.0     M:Males  Y15-74:From 15 to 74 years            72.9
#
#               iccs  ...  metroreg_type  \
# 784       ICCS0101  ...              M
# 785       ICCS0401  ...              M
# 786      ICCS05012  ...              M
# 787     ICCS050211  ...              M
# 840       ICCS0101  ...              M
# ...            ...  ...            ...
# 136671  ICCS050211  ...              N
# 136672    ICCS0101  ...              N
# 136673    ICCS0401  ...              N
# 136674   ICCS05012  ...              N
# 136675  ICCS050211  ...              N
#
#                                           iccs_d crime/population     density  \
# 784                         Intentional homicide         0.000004  304.102643
# 785                                      Robbery         0.000946  304.102643
# 786     Burglary of private residential premises         0.004016  304.102643
# 787            Theft of a motorized land vehicle         0.000160  304.102643
# 840                         Intentional homicide         0.000004  308.558126
# ...                                          ...              ...         ...
# 136671         Theft of a motorized land vehicle         0.000164   99.105623
# 136672                      Intentional homicide         0.000010   99.105623
# 136673                                   Robbery         0.000051   99.105623
# 136674  Burglary of private residential premises         0.000167   99.105623
# 136675         Theft of a motorized land vehicle         0.000164   99.105623
#
#         crime/density  crime/population_log  density_log  crime/density_log  \
# 784          0.039460            -12.316896     5.717365          -3.232459
# 785          8.342578             -6.963065     5.717365           2.121372
# 786         35.409097             -5.517468     5.717365           3.566969
# 787          1.410708             -8.740345     5.717365           0.344092
# 840          0.035650            -12.418452     5.731910          -3.334015
# ...               ...                   ...          ...                ...
# 136671       6.588930             -8.716928     4.596186           1.885391
# 136672       0.413700            -11.484933     4.596186          -0.882614
# 136673       2.038229             -9.890237     4.596186           0.712082
# 136674       6.730193             -8.695715     4.596186           1.906604
# 136675       6.588930             -8.716928     4.596186           1.885391
#
#         unemp_log    gdp_log
# 784      2.639057  10.659610
# 785      2.639057  10.659610
# 786      2.639057  10.659610
# 787      2.639057  10.659610
# 840      2.667228  10.673596
# ...           ...        ...
# 136671   2.580217   9.546813
# 136672   4.289089   9.546813
# 136673   4.289089   9.546813
# 136674   4.289089   9.546813
# 136675   4.289089   9.546813
#
# [5618 rows x 22 columns]

# %%
df.head()
# Out:
#     metroreg  TIME_PERIOD                         unit      gdp    area  \
# 784  AT001MC         2014  EUR_HAB:Euro per inhabitant  42600.0  8817.0
# 785  AT001MC         2014  EUR_HAB:Euro per inhabitant  42600.0  8817.0
# 786  AT001MC         2014  EUR_HAB:Euro per inhabitant  42600.0  8817.0
# 787  AT001MC         2014  EUR_HAB:Euro per inhabitant  42600.0  8817.0
# 840  AT001MC         2015  EUR_HAB:Euro per inhabitant  43200.0  8817.0
#
#      population dfunemp_sex                 dfunemp_age  unemp per Tsd.  \
# 784   2681273.0     M:Males  Y15-24:From 15 to 24 years            14.0
# 785   2681273.0     M:Males  Y15-24:From 15 to 24 years            14.0
# 786   2681273.0     M:Males  Y15-24:From 15 to 24 years            14.0
# 787   2681273.0     M:Males  Y15-24:From 15 to 24 years            14.0
# 840   2720557.0     M:Males  Y15-24:From 15 to 24 years            14.4
#
#            iccs  ...  metroreg_d metroreg_type  \
# 784    ICCS0101  ...        Wien             M
# 785    ICCS0401  ...        Wien             M
# 786   ICCS05012  ...        Wien             M
# 787  ICCS050211  ...        Wien             M
# 840    ICCS0101  ...        Wien             M
#
#                                        iccs_d crime/population     density  \
# 784                      Intentional homicide         0.000004  304.102643
# 785                                   Robbery         0.000946  304.102643
# 786  Burglary of private residential premises         0.004016  304.102643
# 787         Theft of a motorized land vehicle         0.000160  304.102643
# 840                      Intentional homicide         0.000004  308.558126
#
#      crime/density  crime/population_log  density_log  crime/density_log  \
# 784       0.039460            -12.316896     5.717365          -3.232459
# 785       8.342578             -6.963065     5.717365           2.121372
# 786      35.409097             -5.517468     5.717365           3.566969
# 787       1.410708             -8.740345     5.717365           0.344092
# 840       0.035650            -12.418452     5.731910          -3.334015
#
#      unemplog
# 784  2.639057
# 785  2.639057
# 786  2.639057
# 787  2.639057
# 840  2.667228
#
# [5 rows x 21 columns]

# %%
# select year
def select_year(df, year):
    df = df[df['TIME_PERIOD'] == year]
    return df

# group by type of crime
def group_by_iccs(df):
    df = df.groupby(['metroreg', 'iccs_d']).first().reset_index()   
    return df

# plot scatterplot, correlations
def plot_scatterplot(df, x, y):
    for crime_type in df['iccs_d'].unique():
        subset = df[df['iccs_d'] == crime_type]
        plot = sns.scatterplot(x=x, y=y, data=subset)
        m,b = np.polyfit(subset[x], subset[y], 1)
        plot.plot(subset[x], m*subset[x] + b, color = 'red')
        plt.show()
        print(f'Correlation for {crime_type}:\n {subset[[x, y]].corr()}')

# %%
df = df.dropna(subset=['unemp_log'])

# %%
# select year
df_year = select_year(df, 2019)

# group by type of crime
df_year_grouped = group_by_iccs(df_year)

# plot scatterplot, correlations
# plot_scatterplot(df_year_grouped, 'density_log', 'crime/population_log')
# plot_scatterplot(df_year_grouped, 'unemp per Tsd.', 'crime/density_log')

# %%
df_year_grouped.head()
# Out:
#   metroreg                                    iccs_d  TIME_PERIOD  \
# 0  AT001MC  Burglary of private residential premises         2020
# 1  AT001MC                      Intentional homicide         2020
# 2  AT001MC                                   Robbery         2020
# 3  AT001MC         Theft of a motorized land vehicle         2020
# 4   AT002M  Burglary of private residential premises         2020
#
#                           unit      gdp    area  population dfunemp_sex  \
# 0  EUR_HAB:Euro per inhabitant  45100.0  8817.0   2873995.0     M:Males
# 1  EUR_HAB:Euro per inhabitant  45100.0  8817.0   2873995.0     M:Males
# 2  EUR_HAB:Euro per inhabitant  45100.0  8817.0   2873995.0     M:Males
# 3  EUR_HAB:Euro per inhabitant  45100.0  8817.0   2873995.0     M:Males
# 4  EUR_HAB:Euro per inhabitant  44000.0  3479.0    642134.0     M:Males
#
#                   dfunemp_age  unemp per Tsd.  ... Nr_Crimes  metroreg_d  \
# 0  Y15-24:From 15 to 24 years            11.3  ...      3213        Wien
# 1  Y15-24:From 15 to 24 years            11.3  ...        18        Wien
# 2  Y15-24:From 15 to 24 years            11.3  ...      1269        Wien
# 3  Y15-24:From 15 to 24 years            11.3  ...       447        Wien
# 4  Y15-74:From 15 to 74 years             9.0  ...       420        Graz
#
#   metroreg_type crime/population     density  crime/density  \
# 0             M         0.001118  325.960644       9.857018
# 1             M         0.000006  325.960644       0.055221
# 2             M         0.000442  325.960644       3.893108
# 3             M         0.000156  325.960644       1.371331
# 4             M         0.000654  184.574303       2.275506
#
#    crime/population_log  density_log  crime/density_log  unemp_log
# 0             -6.796253     5.786777           2.288184   2.424803
# 1            -11.980842     5.786777          -2.896405   2.424803
# 2             -7.725229     5.786777           1.359208   2.424803
# 3             -8.768655     5.786777           0.315782   2.424803
# 4             -7.332298     5.218052           0.822203   2.197225
#
# [5 rows x 21 columns]

# %%
# Loop over the unique 'iccs_d' values in the DataFrame
for iccs in df_year_grouped['iccs_d'].unique():
    # Create a subset of the DataFrame that only contains the rows with the current 'iccs_d' value
    subset = df_year_grouped[df_year_grouped['iccs_d'] == iccs]

    # Calculate the correlation matrix for the subset
    corr = subset[['crime/population', 'density_log', 'crime/population_log',  'crime/density_log', 'unemp per Tsd.', 'gdp', 'population', 'Nr_Crimes', 'unemp_log', 'gdp_log']].corr()

    # Plot the heatmap
    plt.figure(figsize=(10, 10))
    sns.heatmap(corr, annot=True)
    plt.title(f'Correlation Heatmap for iccs_d = {iccs}')
    plt.show()

# %%
# testing stabilty of correlations over the years

for iccs_value in df['iccs_d'].unique():
    correlation_data = []

    for year in df['TIME_PERIOD'].unique():
        df_year = df[df['TIME_PERIOD'] == year]
        # Create a subset of the DataFrame that only contains the rows with the current 'iccs_d' value
        subset = df_year[df_year['iccs_d'] == iccs_value]
        # Calculate the correlation matrix for the subset
        corr = subset[['crime/population', 'density_log', 'crime/population_log',  
                       'crime/density_log', 'unemp per Tsd.', 'gdp', 'population',
                       'Nr_Crimes', 'unemp_log', 'gdp_log']].corr()
        
        # Iterate over the columns of the correlation matrix
        for factor in corr.columns:
            correlation_data.append({
                'year': year,
                'iccs': iccs_value,
                'factor': factor,
                'correlation': corr.loc[factor, 'crime/population_log']     # target variable
            })

    # Create a DataFrame from the collected correlation data
    correlation_df = pd.DataFrame(correlation_data)

    # Plot using seaborn
    plt.figure(figsize=(12, 8))
    sns.lineplot(x='year', y='correlation', hue='factor', data=correlation_df)
    plt.title(f'Correlation Trends Over Time for ICCS {iccs_value}')
    plt.show()

# %%
# regression model using k fold
def regression_model(df, x, y):
    # Reset the index of the DataFrame
    df = df.reset_index(drop=True)
    
    # Split data
    kf = KFold(n_splits=5, shuffle=True)
    kf.get_n_splits(df)
    
    # Create model
    coefficients = []
    r2_scores = []
    model = LinearRegression()
    
    # Train model
    for train_index, test_index in kf.split(df):
        X_train, X_test = df.iloc[train_index][x], df.iloc[test_index][x]
        y_train, y_test = df.iloc[train_index][y], df.iloc[test_index][y]
        
        model.fit(X_train, y_train)
        
        coefficients.append(model.coef_)
        r2_scores.append(model.score(X_test, y_test))
    
    # Return the trained model
    return np.mean(coefficients), np.mean(r2_scores)

# %%
for iccs in df_year_grouped['iccs_d'].unique():
    subset = df_year_grouped[df_year_grouped['iccs_d'] == iccs]
    mean_r2 = regression_model(subset, ['density_log', 'unemp_log', 'gdp_log'], ['crime/population_log'])
    print("{:-^50}".format(iccs))
    print(f"Mean R2: {mean_r2[1]}", sep='\n')
# Out:
# -----Burglary of private residential premises-----
# Mean R2: 0.14860367234258906
# ---------------Intentional homicide---------------
# Mean R2: -1.2534384115789072
# ---------------------Robbery----------------------
# Mean R2: 0.24307396101270262
# --------Theft of a motorized land vehicle---------
# Mean R2: 0.2119246464131007

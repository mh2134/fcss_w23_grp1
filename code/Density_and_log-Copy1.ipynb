# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Metropolitan area

# %%
# read df
df = pd.read_csv(r'../data/df_allmetro_all.csv')

# calculate relative crime
df.loc[:, 'crime/population'] = df['Nr_Crimes'] / df['population']
df.loc[:, 'density'] = df['population'] / df['area']
df.loc[:, 'crime/density'] = df['Nr_Crimes'] / df['density']

# log columns
df.loc[:, 'crime/population_log'] = np.log(df['crime/population'] + 1e-20)  # add small number to avoid log(0)
df.loc[:, 'density_log'] = np.log(df['density'] + 1e-20)
df.loc[:, 'crime/density_log'] = np.log(df['crime/density'] + 1e-20)
df.loc[:, 'unemp_log'] = np.log(df['unemp per Tsd.'] + 1e-20)
df.loc[:, 'gdp_log'] = np.log(df['gdp'] + 1e-20)

# drop aggregates
df = df[df['metroreg'].str.len() >= 3]

# drop values
df = df[(df['unit'] == 'EUR_HAB:Euro per inhabitant') & (df['dfunemp_sex'] == 'M:Males')]

df.dropna()
# Out:
#       metroreg  TIME_PERIOD                         unit      gdp     area  \
# 592    AT001MC         2017  EUR_HAB:Euro per inhabitant  44900.0   8817.0
# 593    AT001MC         2017  EUR_HAB:Euro per inhabitant  44900.0   8817.0
# 594    AT001MC         2017  EUR_HAB:Euro per inhabitant  44900.0   8817.0
# 595    AT001MC         2017  EUR_HAB:Euro per inhabitant  44900.0   8817.0
# 676    AT001MC         2018  EUR_HAB:Euro per inhabitant  46600.0   8817.0
# ...        ...          ...                          ...      ...      ...
# 88368    SK_NM         2019  EUR_HAB:Euro per inhabitant  14200.0  40228.0
# 88449    SK_NM         2020  EUR_HAB:Euro per inhabitant  14000.0  40228.0
# 88450    SK_NM         2020  EUR_HAB:Euro per inhabitant  14000.0  40228.0
# 88451    SK_NM         2020  EUR_HAB:Euro per inhabitant  14000.0  40228.0
# 88452    SK_NM         2020  EUR_HAB:Euro per inhabitant  14000.0  40228.0
#
#        population dfunemp_sex                 dfunemp_age  unemp per Tsd.  \
# 592     2811186.0     M:Males  Y15-74:From 15 to 74 years            71.2
# 593     2811186.0     M:Males  Y15-74:From 15 to 74 years            71.2
# 594     2811186.0     M:Males  Y15-74:From 15 to 74 years            71.2
# 595     2811186.0     M:Males  Y15-74:From 15 to 74 years            71.2
# 676     2838558.0     M:Males  Y15-74:From 15 to 74 years            67.3
# ...           ...         ...                         ...             ...
# 88368   3990409.0     M:Males  Y15-74:From 15 to 74 years            63.4
# 88449   3986821.0     M:Males  Y15-74:From 15 to 74 years            72.9
# 88450   3986821.0     M:Males  Y15-74:From 15 to 74 years            72.9
# 88451   3986821.0     M:Males  Y15-74:From 15 to 74 years            72.9
# 88452   3986821.0     M:Males  Y15-74:From 15 to 74 years            72.9
#
#              iccs  ...  crimes_rate     density  unemp_area crime/population  \
# 592      ICCS0101  ...     0.640299  318.837019  807.530906         0.000006
# 593      ICCS0401  ...    59.939115  318.837019  807.530906         0.000599
# 594     ICCS05012  ...   237.550984  318.837019  807.530906         0.002376
# 595    ICCS050211  ...    16.861211  318.837019  807.530906         0.000169
# 676      ICCS0101  ...     1.444395  321.941477  763.298174         0.000014
# ...           ...  ...          ...         ...         ...              ...
# 88368  ICCS050211  ...    16.589778   99.194815  157.601670         0.000166
# 88449    ICCS0101  ...     1.028388   99.105623  181.217063         0.000010
# 88450    ICCS0401  ...     5.066693   99.105623  181.217063         0.000051
# 88451   ICCS05012  ...    16.730122   99.105623  181.217063         0.000167
# 88452  ICCS050211  ...    16.378965   99.105623  181.217063         0.000164
#
#        crime/density  crime/population_log  density_log  crime/density_log  \
# 592         0.056455            -11.958745     5.764680          -2.874308
# 593         5.284832             -7.419596     5.764680           1.664841
# 594        20.944870             -6.042543     5.764680           3.041894
# 595         1.486653             -8.687910     5.764680           0.396527
# 676         0.127352            -11.145235     5.774370          -2.060798
# ...              ...                   ...          ...                ...
# 88368       6.673736             -8.704139     4.597086           1.898180
# 88449       0.413700            -11.484933     4.596186          -0.882614
# 88450       2.038229             -9.890237     4.596186           0.712082
# 88451       6.730193             -8.695715     4.596186           1.906604
# 88452       6.588930             -8.716928     4.596186           1.885391
#
#        unemp_log    gdp_log
# 592     4.265493  10.712193
# 593     4.265493  10.712193
# 594     4.265493  10.712193
# 595     4.265493  10.712193
# 676     4.209160  10.749356
# ...          ...        ...
# 88368   4.149464   9.560997
# 88449   4.289089   9.546813
# 88450   4.289089   9.546813
# 88451   4.289089   9.546813
# 88452   4.289089   9.546813
#
# [2720 rows x 25 columns]

# %%
df.head()
# Out:
#     metroreg  TIME_PERIOD                         unit      gdp    area  \
# 592  AT001MC         2017  EUR_HAB:Euro per inhabitant  44900.0  8817.0
# 593  AT001MC         2017  EUR_HAB:Euro per inhabitant  44900.0  8817.0
# 594  AT001MC         2017  EUR_HAB:Euro per inhabitant  44900.0  8817.0
# 595  AT001MC         2017  EUR_HAB:Euro per inhabitant  44900.0  8817.0
# 676  AT001MC         2018  EUR_HAB:Euro per inhabitant  46600.0  8817.0
#
#      population dfunemp_sex                 dfunemp_age  unemp per Tsd.  \
# 592   2811186.0     M:Males  Y15-74:From 15 to 74 years            71.2
# 593   2811186.0     M:Males  Y15-74:From 15 to 74 years            71.2
# 594   2811186.0     M:Males  Y15-74:From 15 to 74 years            71.2
# 595   2811186.0     M:Males  Y15-74:From 15 to 74 years            71.2
# 676   2838558.0     M:Males  Y15-74:From 15 to 74 years            67.3
#
#            iccs  ...  crimes_rate     density  unemp_area crime/population  \
# 592    ICCS0101  ...     0.640299  318.837019  807.530906         0.000006
# 593    ICCS0401  ...    59.939115  318.837019  807.530906         0.000599
# 594   ICCS05012  ...   237.550984  318.837019  807.530906         0.002376
# 595  ICCS050211  ...    16.861211  318.837019  807.530906         0.000169
# 676    ICCS0101  ...     1.444395  321.941477  763.298174         0.000014
#
#      crime/density  crime/population_log  density_log  crime/density_log  \
# 592       0.056455            -11.958745      5.76468          -2.874308
# 593       5.284832             -7.419596      5.76468           1.664841
# 594      20.944870             -6.042543      5.76468           3.041894
# 595       1.486653             -8.687910      5.76468           0.396527
# 676       0.127352            -11.145235      5.77437          -2.060798
#
#      unemp_log    gdp_log
# 592   4.265493  10.712193
# 593   4.265493  10.712193
# 594   4.265493  10.712193
# 595   4.265493  10.712193
# 676   4.209160  10.749356
#
# [5 rows x 25 columns]

# %%
# select year
def select_year(df, year):
    df = df[df['TIME_PERIOD'] == year]
    return df

# group by type of crime
def group_by_iccs(df):
    df = df.groupby(['metroreg', 'iccs_d']).first().reset_index()   
    return df

# plot scatterplot, correlations
def plot_scatterplot(df, x, y):
    for crime_type in df['iccs_d'].unique():
        subset = df[df['iccs_d'] == crime_type]
        plot = sns.scatterplot(x=x, y=y, data=subset)
        m,b = np.polyfit(subset[x], subset[y], 1)
        plot.plot(subset[x], m*subset[x] + b, color = 'red')
        plt.show()
        print(f'Correlation for {crime_type}:\n {subset[[x, y]].corr()}')

# %%
df = df.dropna(subset=['unemp_log'])

# %%
# select year
df_year = select_year(df, 2019)

# group by type of crime
df_year_grouped = group_by_iccs(df_year)

# plot scatterplot, correlations
# plot_scatterplot(df_year_grouped, 'density_log', 'crime/population_log')
# plot_scatterplot(df_year_grouped, 'unemp per Tsd.', 'crime/density_log')

# %%
df_year_grouped.head()
# Out:
#   metroreg                                    iccs_d  TIME_PERIOD  \
# 0  AT001MC  Burglary of private residential premises         2019
# 1  AT001MC                      Intentional homicide         2019
# 2  AT001MC                                   Robbery         2019
# 3  AT001MC         Theft of a motorized land vehicle         2019
# 4   AT002M  Burglary of private residential premises         2019
#
#                           unit      gdp    area  population dfunemp_sex  \
# 0  EUR_HAB:Euro per inhabitant  47800.0  8817.0   2853903.0     M:Males
# 1  EUR_HAB:Euro per inhabitant  47800.0  8817.0   2853903.0     M:Males
# 2  EUR_HAB:Euro per inhabitant  47800.0  8817.0   2853903.0     M:Males
# 3  EUR_HAB:Euro per inhabitant  47800.0  8817.0   2853903.0     M:Males
# 4  EUR_HAB:Euro per inhabitant  45700.0  3479.0    637532.0     M:Males
#
#                   dfunemp_age  unemp per Tsd.  ... crimes_rate     density  \
# 0  Y15-74:From 15 to 74 years            62.0  ...  169.697428  323.681865
# 1  Y15-74:From 15 to 74 years            62.0  ...    1.121271  323.681865
# 2  Y15-74:From 15 to 74 years            62.0  ...   56.308851  323.681865
# 3  Y15-74:From 15 to 74 years            62.0  ...   15.172205  323.681865
# 4  Y15-74:From 15 to 74 years             6.0  ...  100.073408  183.251509
#
#    unemp_area crime/population  crime/density  crime/population_log  \
# 0  703.187025         0.001697      14.962222             -6.378908
# 1  703.187025         0.000011       0.098863            -11.398462
# 2  703.187025         0.000563       4.964751             -7.482074
# 3  703.187025         0.000152       1.337733             -8.793460
# 4  172.463352         0.001001       3.481554             -6.907021
#
#    density_log  crime/density_log  unemp_log    gdp_log
# 0     5.779761           2.705529   4.127134  10.774781
# 1     5.779761          -2.314025   4.127134  10.774781
# 2     5.779761           1.602363   4.127134  10.774781
# 3     5.779761           0.290977   4.127134  10.774781
# 4     5.210860           1.247479   1.791759  10.729854
#
# [5 rows x 25 columns]

# %%
# Loop over the unique 'iccs_d' values in the DataFrame
for iccs in df_year_grouped['iccs_d'].unique():
    # Create a subset of the DataFrame that only contains the rows with the current 'iccs_d' value
    subset = df_year_grouped[df_year_grouped['iccs_d'] == iccs]

    # Calculate the correlation matrix for the subset
    corr = subset[['crime/population', 'density_log', 'crime/population_log',  'crime/density_log', 'unemp per Tsd.', 'gdp', 'population', 'Nr_Crimes', 'unemp_log', 'gdp_log']].corr()

    # Plot the heatmap
    plt.figure(figsize=(10, 10))
    sns.heatmap(corr, annot=True, cmap='bwr')
    plt.title(f'Correlation Heatmap for iccs_d = {iccs}')
    plt.show()

# %%
# testing stabilty of correlations over the years

for iccs_value in df['iccs_d'].unique():
    correlation_data = []

    for year in df['TIME_PERIOD'].unique():
        df_year = df[df['TIME_PERIOD'] == year]
        # Create a subset of the DataFrame that only contains the rows with the current 'iccs_d' value
        subset = df_year[df_year['iccs_d'] == iccs_value]
        # Calculate the correlation matrix for the subset
        corr = subset[['crime/population', 'density_log', 'crime/population_log',  
                       'crime/density_log', 'unemp per Tsd.', 'gdp', 'population',
                       'Nr_Crimes', 'unemp_log', 'gdp_log']].corr()
        
        # Iterate over the columns of the correlation matrix
        for factor in corr.columns:
            correlation_data.append({
                'year': year,
                'iccs': iccs_value,
                'factor': factor,
                'correlation': corr.loc[factor, 'crime/population_log']     # target variable
            })

    # Create a DataFrame from the collected correlation data
    correlation_df = pd.DataFrame(correlation_data)

    # Plot using seaborn
    plt.figure(figsize=(12, 8))
    sns.lineplot(x='year', y='correlation', hue='factor', data=correlation_df)
    plt.title(f'Correlation Trends Over Time for ICCS {iccs_value}')
    plt.show()
# Out:
# C:\Users\zmugm1\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\zmugm1\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\zmugm1\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\zmugm1\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\zmugm1\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\zmugm1\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\zmugm1\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\zmugm1\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# regression model using k fold
def regression_model(df, x, y):
    # Reset the index of the DataFrame
    df = df.reset_index(drop=True)
    
    # Split data
    kf = KFold(n_splits=5, shuffle=True)
    kf.get_n_splits(df)
    
    # Create model
    coefficients = []
    r2_scores = []
    model = LinearRegression()
    
    # Train model
    for train_index, test_index in kf.split(df):
        X_train, X_test = df.iloc[train_index][x], df.iloc[test_index][x]
        y_train, y_test = df.iloc[train_index][y], df.iloc[test_index][y]
        
        model.fit(X_train, y_train)
        
        coefficients.append(model.coef_)
        r2_scores.append(model.score(X_test, y_test))
    
    # Return the trained model
    return np.mean(coefficients), np.mean(r2_scores)

# %%
for iccs in df_year_grouped['iccs_d'].unique():
    subset = df_year_grouped[df_year_grouped['iccs_d'] == iccs]
    mean_r2 = regression_model(subset, ['density_log', 'unemp_log', 'gdp_log'], ['crime/population_log'])
    print("{:-^50}".format(iccs))
    print(f"Mean R2: {mean_r2[1]}", sep='\n')
# Out:
# -----Burglary of private residential premises-----
# Mean R2: 0.08281072507876792
# ---------------Intentional homicide---------------
# Mean R2: -3.290362391155521
# ---------------------Robbery----------------------
# Mean R2: 0.3399172395024124
# --------Theft of a motorized land vehicle---------
# Mean R2: 0.30116820681521983
